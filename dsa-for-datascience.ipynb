# %% [markdown]
# <a href="https://www.kaggle.com/code/madushaninimeshika/dsa-for-datascience?scriptVersionId=207070736" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Lets say two dictionaries food and orders by considering the total time for each order sort them in accending order.

# %%
food = {
    "Koththu" : 10,
    "CRice" : 9,
    "CheeseKoththu" : 20,
    "Milkshake" : 5,
    "Chips" : 2,
    "Desert" : 6,
    "Parata" : 3,
    "BeefKoththu" : 25,
    "Biriyani" : 30,
    "Roti": 5,
    "BeefCurry" : 22,
    "ChickenCurry" : 21,
    "MuttonCurry" : 40
            }

food
# Out:
# {'Koththu': 10,
#  'CRice': 9,
#  'CheeseKoththu': 20,
#  'Milkshake': 5,
#  'Chips': 2,
#  'Desert': 6,
#  'Parata': 3,
#  'BeefKoththu': 25,
#  'Biriyani': 30,
#  'Roti': 5,
#  'BeefCurry': 22,
#  'ChickenCurry': 21,
#  'MuttonCurry': 40}

# %%
import random

orders = {}

# List of available food items for generating random combinations
food_items = list(food.keys())

for i in range(1, 21): # loop to create 20 orders
    order_items = {}

    # Randomly select 2-5 food items per order
    items_in_order = random.sample(food_items, random.randint(2, 5))

    for item in items_in_order:
        # Random quantity between 1 and 3 for each item in the order
        order_items[item] = random.randint(1, 3)

    # Add the generate order to the main orders dictionary
    orders[str(i)] = order_items
print(orders, sep="\n")
# Out:
# {'1': {'BeefKoththu': 3, 'Parata': 2, 'Chips': 2, 'BeefCurry': 2, 'Biriyani': 1}, '2': {'Milkshake': 3, 'Parata': 3, 'Koththu': 3}, '3': {'Desert': 2, 'CheeseKoththu': 3, 'BeefCurry': 3, 'Milkshake': 1}, '4': {'BeefKoththu': 2, 'BeefCurry': 1}, '5': {'Desert': 1, 'BeefKoththu': 2, 'Koththu': 1, 'Parata': 3}, '6': {'CheeseKoththu': 3, 'Milkshake': 2, 'Koththu': 2, 'Parata': 3}, '7': {'Desert': 1, 'MuttonCurry': 3, 'Biriyani': 3, 'CheeseKoththu': 1}, '8': {'Milkshake': 1, 'Chips': 3, 'ChickenCurry': 3, 'Biriyani': 2}, '9': {'Biriyani': 3, 'BeefCurry': 1}, '10': {'Roti': 2, 'Milkshake': 1}, '11': {'MuttonCurry': 3, 'Desert': 2, 'Roti': 2, 'Chips': 3, 'Parata': 3}, '12': {'Koththu': 1, 'Biriyani': 2, 'MuttonCurry': 2}, '13': {'Milkshake': 2, 'Parata': 2, 'Koththu': 3, 'BeefKoththu': 3}, '14': {'Biriyani': 2, 'Desert': 3, 'BeefCurry': 2}, '15': {'Koththu': 3, 'Milkshake': 2}, '16': {'ChickenCurry': 1, 'Roti': 3, 'CRice': 1, 'CheeseKoththu': 1}, '17': {'Biriyani': 2, 'Parata': 3, 'CheeseKoththu': 3, 'BeefKoththu': 1}, '18': {'CRice': 1, 'MuttonCurry': 1, 'Desert': 1}, '19': {'CRice': 2, 'BeefKoththu': 2, 'Milkshake': 2, 'Biriyani': 3}, '20': {'Koththu': 2, 'ChickenCurry': 2, 'CheeseKoththu': 1}}

# %%
orders
# Out:
# {'1': {'BeefKoththu': 3,
#   'Parata': 2,
#   'Chips': 2,
#   'BeefCurry': 2,
#   'Biriyani': 1},
#  '2': {'Milkshake': 3, 'Parata': 3, 'Koththu': 3},
#  '3': {'Desert': 2, 'CheeseKoththu': 3, 'BeefCurry': 3, 'Milkshake': 1},
#  '4': {'BeefKoththu': 2, 'BeefCurry': 1},
#  '5': {'Desert': 1, 'BeefKoththu': 2, 'Koththu': 1, 'Parata': 3},
#  '6': {'CheeseKoththu': 3, 'Milkshake': 2, 'Koththu': 2, 'Parata': 3},
#  '7': {'Desert': 1, 'MuttonCurry': 3, 'Biriyani': 3, 'CheeseKoththu': 1},
#  '8': {'Milkshake': 1, 'Chips': 3, 'ChickenCurry': 3, 'Biriyani': 2},
#  '9': {'Biriyani': 3, 'BeefCurry': 1},
#  '10': {'Roti': 2, 'Milkshake': 1},
#  '11': {'MuttonCurry': 3, 'Desert': 2, 'Roti': 2, 'Chips': 3, 'Parata': 3},
#  '12': {'Koththu': 1, 'Biriyani': 2, 'MuttonCurry': 2},
#  '13': {'Milkshake': 2, 'Parata': 2, 'Koththu': 3, 'BeefKoththu': 3},
#  '14': {'Biriyani': 2, 'Desert': 3, 'BeefCurry': 2},
#  '15': {'Koththu': 3, 'Milkshake': 2},
#  '16': {'ChickenCurry': 1, 'Roti': 3, 'CRice': 1, 'CheeseKoththu': 1},
#  '17': {'Biriyani': 2, 'Parata': 3, 'CheeseKoththu': 3, 'BeefKoththu': 1},
#  '18': {'CRice': 1, 'MuttonCurry': 1, 'Desert': 1},
#  '19': {'CRice': 2, 'BeefKoththu': 2, 'Milkshake': 2, 'Biriyani': 3},
#  '20': {'Koththu': 2, 'ChickenCurry': 2, 'CheeseKoththu': 1}}

# %%
def calculate_time(food, orders):
    
    resdict = {}

    # aculate the preparation time for each order
    for orderId, items in orders.items(): # Outer loop : looping through the orders 
        
        orderTime = 0 # orderTime begin of each order is set to zero

        for item, quantity in items.items(): # Inner loop
            if item in food:
                orderTime += food[item] * quantity
        
        resdict[orderId] = orderTime # store the total time for the current order

    # sort the orers by their preparation time
    sorted_dict = dict(sorted(resdict.items(), key=lambda x : x[1]))

    # Print the sorted orders
    for orderId, time in sorted_dict.items():
        print(f'Order {orderId} : {time} minutes')

calculate_time(food,orders)
# Out:
# Order 10 : 15 minutes
# Order 15 : 40 minutes
# Order 2 : 54 minutes
# Order 18 : 55 minutes
# Order 16 : 65 minutes
# Order 4 : 72 minutes
# Order 5 : 75 minutes
# Order 20 : 82 minutes
# Order 6 : 99 minutes
# Order 9 : 112 minutes
# Order 13 : 121 minutes
# Order 14 : 122 minutes
# Order 8 : 134 minutes
# Order 3 : 143 minutes
# Order 12 : 150 minutes
# Order 17 : 154 minutes
# Order 11 : 157 minutes
# Order 1 : 159 minutes
# Order 19 : 168 minutes
# Order 7 : 236 minutes
